# %%
import os
import re
import fitz 
import docx

# %%
try:
    import win32com.client
except ImportError:
    win32com = None

# %%
def extract_text_from_pdf(pdf_path):
    """Trích xuất toàn bộ văn bản từ file PDF."""
    text = ""
    doc = fitz.open(pdf_path)
    for page in doc:
        text += page.get_text("text") + "\n"
    return text

# %%
def extract_text_from_doc(doc_path):
    """
    Trích xuất văn bản từ file DOC (.doc) sử dụng COM automation của MS Word.
    Chỉ sử dụng trên Windows khi đã cài Microsoft Word và pywin32.
    """
    if win32com is None:
        raise ImportError("win32com module not found. Vui lòng cài đặt pywin32 để xử lý file .doc.")
    
    word = win32com.client.Dispatch("Word.Application")
    word.Visible = False
    abs_path = os.path.abspath(doc_path)
    try:
        doc = word.Documents.Open(abs_path)
        text = doc.Range().Text
        doc.Close(False)
    except Exception as e:
        print(f"Lỗi khi xử lý {doc_path}: {e}")
        text = ""
    finally:
        word.Quit()
    return text

# %%
def sanitize_name(name):
    """
    Loại bỏ các ký tự không hợp lệ cho tên file/folder 
    và loại bỏ khoảng trắng thừa.
    """
    return re.sub(r'[\\/*?:"<>|]', "", name).strip()

def prepare_filename(name, max_length=150):
    """
    Chuẩn hóa tên: loại bỏ ký tự không hợp lệ và rút gọn nếu độ dài vượt quá max_length.
    """
    name = sanitize_name(name)
    if len(name) > max_length:
        name = name[:max_length]
    return name

# %%
def extract_text_from_docx(docx_path):
    """Trích xuất toàn bộ văn bản từ file DOCX."""
    text = ""
    doc = docx.Document(docx_path)
    for para in doc.paragraphs:
        text += para.text + "\n"
    return text

# %%
def split_into_chapters(text):
    """
    Tách văn bản thành các chương dựa trên marker "Chương ...".
    Nếu không tìm thấy marker, toàn bộ nội dung sẽ được gán vào "Chương 1".
    """
    pattern = re.compile(r"^(Chương\s+\S.*)$", re.MULTILINE)
    matches = list(pattern.finditer(text))
    chapters = []
    if not matches:
        chapters.append(("Chương 1", text.strip()))
    else:
        for i, match in enumerate(matches):
            chap_title = match.group(1).strip()
            start = match.start()
            end = matches[i+1].start() if (i+1) < len(matches) else len(text)
            chap_text = text[start:end].strip()
            chapters.append((chap_title, chap_text))
    return chapters

# %%
def split_into_clauses(chap_text):
    """
    Tách nội dung của một chương thành các điều dựa trên marker "Điều ...".
    Nếu không tìm thấy marker, toàn bộ nội dung chương được gán vào "Điều 1".
    """
    pattern = re.compile(r"^(Điều\s+\d+.*)$", re.MULTILINE)
    matches = list(pattern.finditer(chap_text))
    clauses = []
    if not matches:
        clauses.append(("Điều 1", chap_text.strip()))
    else:
        for i, match in enumerate(matches):
            clause_title = match.group(1).strip()
            start = match.start()
            end = matches[i+1].start() if (i+1) < len(matches) else len(chap_text)
            clause_text = chap_text[start:end].strip()
            clauses.append((clause_title, clause_text))
    return clauses

# %%
def save_text(text, output_path):
    """
    Lưu văn bản ra file text với encoding UTF-8.
    Đảm bảo rằng thư mục chứa file đã được tạo.
    """
    folder = os.path.dirname(output_path)
    os.makedirs(folder, exist_ok=True)
    with open(output_path, "w", encoding="utf-8") as f:
        f.write(text)

# %%
def process_file(file_path, relative_path, output_folder):
    """
    Xử lý một file (PDF, DOCX, DOC):
      - Trích xuất văn bản từ file.
      - Tách văn bản thành các chương và trong mỗi chương tách ra các điều.
      - Lưu kết quả vào folder output_folder với cấu trúc:
            output_folder/relative_path/<tên file đã chuẩn hóa>/Chương_X/Điều_Y.txt
    """
    print(f"Đang xử lý file: {file_path}")
    
    if file_path.lower().endswith(".pdf"):
        full_text = extract_text_from_pdf(file_path)
    elif file_path.lower().endswith(".docx"):
        full_text = extract_text_from_docx(file_path)
    elif file_path.lower().endswith(".doc"):
        full_text = extract_text_from_doc(file_path)
    else:
        return

    chapters = split_into_chapters(full_text)
    base_name = os.path.splitext(os.path.basename(file_path))[0]
    base_output_dir = os.path.join(output_folder, relative_path, prepare_filename(base_name))
    os.makedirs(base_output_dir, exist_ok=True)

    for chap_title, chap_text in chapters:
        chap_folder_name = prepare_filename(chap_title)
        chapter_folder_path = os.path.join(base_output_dir, chap_folder_name)
        os.makedirs(chapter_folder_path, exist_ok=True)

        clauses = split_into_clauses(chap_text)
        for clause_title, clause_text in clauses:
            clause_file_name = prepare_filename(clause_title) + ".txt"
            output_file = os.path.join(chapter_folder_path, clause_file_name)
            save_text(clause_text, output_file)
            print(f"Đã lưu: {output_file}")

# %%
def process_file(file_path, relative_path, output_folder):
    """
    Xử lý một file (PDF hoặc DOCX):
      - Trích xuất văn bản.
      - Tách văn bản thành các chương và trong mỗi chương tách thành các điều.
      - Lưu kết quả ra folder mới "data" với cấu trúc:
          output_folder/relative_path/<tên file đã sanitize>/Chương_X/Điều_Y.txt
    """
    print(f"Đang xử lý file: {file_path}")
    
    # Trích xuất nội dung văn bản từ file
    if file_path.lower().endswith(".pdf"):
        full_text = extract_text_from_pdf(file_path)
    elif file_path.lower().endswith(".docx"):
        full_text = extract_text_from_docx(file_path)
    else:
        return

    # Tách nội dung thành các chương
    chapters = split_into_chapters(full_text)
    
    # Tạo folder cơ sở cho file hiện tại (sử dụng tên file đã được sanitize)
    base_name = os.path.splitext(os.path.basename(file_path))[0]
    base_output_dir = os.path.join(output_folder, relative_path, sanitize_name(base_name))
    os.makedirs(base_output_dir, exist_ok=True)

    # Duyệt qua các chương
    for chap_title, chap_text in chapters:
        chap_folder_name = sanitize_name(chap_title)
        chapter_folder_path = os.path.join(base_output_dir, chap_folder_name)
        os.makedirs(chapter_folder_path, exist_ok=True)

        # Tách chương thành các điều và lưu từng điều ra file text riêng
        clauses = split_into_clauses(chap_text)
        for clause_title, clause_text in clauses:
            clause_file_name = sanitize_name(clause_title) + ".txt"
            output_file = os.path.join(chapter_folder_path, clause_file_name)
            save_text(clause_text, output_file)
            print(f"Đã lưu: {output_file}")

# %%
def process_files(input_folder, output_folder):
    """
    Duyệt toàn bộ cây thư mục từ input_folder (ví dụ: "data_crawl")
    và xử lý các file PDF, DOCX, DOC. Kết quả sẽ được lưu vào folder output_folder,
    giữ nguyên cấu trúc thư mục con của input_folder.
    """
    for root, _, files in os.walk(input_folder):
        for file in files:
            if file.lower().endswith((".pdf", ".docx", ".doc")):
                file_path = os.path.join(root, file)
ế chấp.txt
# Đã lưu: data_new\bo_luat_dan_su\bo_luat_dan_su\Chương XV\Điều 304. Bán tài sản cầm cố, thế chấp.txt
# Đã lưu: data_new\bo_luat_dan_su\bo_luat_dan_su\Chương XV\Điều 305. Nhận chính tài sản bảo đảm để thay thế cho việc thực hiện nghĩa.txt
# Đã lưu: data_new\bo_luat_dan_su\bo_luat_dan_su\Chương XV\Điều 306. Định giá tài sản bảo đảm.txt
# Đã lưu: data_new\bo_luat_dan_su\bo_luat_dan_su\Chương XV\Điều 307. Thanh toán số tiền có được từ việc xử lý tài sản cầm cố, thế chấp.txt
# Đã lưu: data_new\bo_luat_dan_su\bo_luat_dan_su\Chương XV\Điều 308. Thứ tự ưu tiên thanh toán giữa các bên cùng nhận tài sản bảo.txt
# Đã lưu: data_new\bo_luat_dan_su\bo_luat_dan_su\Chương XV\Điều 309. Cầm cố tài sản.txt
# Đã lưu: data_new\bo_luat_dan_su\bo_luat_dan_su\Chương XV\Điều 310. Hiệu lực của cầm cố tài sản.txt
# Đã lưu: data_new\bo_luat_dan_su\bo_luat_dan_su\Chương XV\Điều 311. Nghĩa vụ của bên cầm cố.txt
# Đã lưu: data_new\bo_luat_dan_su\bo_luat_dan_su\Chương XV\Điều 312. Quyền của bên cầm cố.txt
# Đã lưu: data_new\bo_luat_dan_su\bo_luat_dan_su\Chương XV\Điều 313. Nghĩa vụ của bên nhận cầm cố.txt
# Đã lưu: data_new\bo_luat_dan_su\bo_luat_dan_su\Chương XV\Điều 314. Quyền của bên nhận cầm cố.txt
# Đã lưu: data_new\bo_luat_dan_su\bo_luat_dan_su\Chương XV\Điều 315. Chấm dứt cầm cố tài sản.txt
# Đã lưu: data_new\bo_luat_dan_su\bo_luat_dan_su\Chương XV\Điều 316. Trả lại tài sản cầm cố.txt
# Đã lưu: data_new\bo_luat_dan_su\bo_luat_dan_su\Chương XV\Điều 317. Thế chấp tài sản.txt
# Đã lưu: data_new\bo_luat_dan_su\bo_luat_dan_su\Chương XV\Điều 318. Tài sản thế chấp.txt
# Đã lưu: data_new\bo_luat_dan_su\bo_luat_dan_su\Chương XV\Điều 319. Hiệu lực của thế chấp tài sản.txt
# Đã lưu: data_new\bo_luat_dan_su\bo_luat_dan_su\Chương XV\Điều 320. Nghĩa vụ của bên thế chấp.txt
# Đã lưu: data_new\bo_luat_dan_su\bo_luat_dan_su\Chương XV\Điều 321. Quyền của bên thế chấp.txt
# Đã lưu: data_new\bo_luat_dan_su\bo_luat_dan_su\Chương XV\Điều 322. Nghĩa vụ của bên nhận thế chấp.txt
# Đã lưu: data_new\bo_luat_dan_su\bo_luat_dan_su\Chương XV\Điều 323. Quyền của bên nhận thế chấp.txt
# Đã lưu: data_new\bo_luat_dan_su\bo_luat_dan_su\Chương XV\Điều 324. Quyền và nghĩa vụ của người thứ ba giữ tài sản thế chấp.txt
# Đã lưu: data_new\bo_luat_dan_su\bo_luat_dan_su\Chương XV\Điều 325. Thế chấp quyền sử dụng đất mà không thế chấp tài sản gắn liền.txt
# Đã lưu: data_new\bo_luat_dan_su\bo_luat_dan_su\Chương XV\Điều 326. Thế chấp tài sản gắn liền với đất mà không thế chấp quyền sử.txt
# Đã lưu: data_new\bo_luat_dan_su\bo_luat_dan_su\Chương XV\Điều 327. Chấm dứt thế chấp tài sản.txt
# Đã lưu: data_new\bo_luat_dan_su\bo_luat_dan_su\Chương XV\Điều 328. Đặt cọc.txt
# Đã lưu: data_new\bo_luat_dan_su\bo_luat_dan_su\Chương XV\Điều 329. Ký cược.txt
# Đã lưu: data_new\bo_luat_dan_su\bo_luat_dan_su\Chương XV\Điều 330. Ký quỹ.txt
# Đã lưu: data_new\bo_luat_dan_su\bo_luat_dan_su\Chương XV\Điều 331. Bảo lưu quyền sở hữu.txt
# Đã lưu: data_new\bo_luat_dan_su\bo_luat_dan_su\Chương XV\Điều 332. Quyền đòi lại tài sản.txt
# Đã lưu: data_new\bo_luat_dan_su\bo_luat_dan_su\Chương XV\Điều 333. Quyền và nghĩa vụ của bên mua tài sản.txt
# Đã lưu: data_new\bo_luat_dan_su\bo_luat_dan_su\Chương XV\Điều 334. Chấm dứt bảo lưu quyền sở hữu.txt
# Đã lưu: data_new\bo_luat_dan_su\bo_luat_dan_su\Chương XV\Điều 335. Bảo lãnh.txt
# Đã lưu: data_new\bo_luat_dan_su\bo_luat_dan_su\Chương XV\Điều 336. Phạm vi bảo lãnh.txt
# Đã lưu: data_new\bo_luat_dan_su\bo_luat_dan_su\Chương XV\Điều 337. Thù lao.txt
# Đã lưu: data_new\bo_luat_dan_su\bo_luat_dan_su\Chương XV\Điều 338. Nhiều người cùng bảo lãnh.txt
# Đã lưu: data_new\bo_luat_dan_su\bo_luat_dan_su\Chương XV\Điều 339. Quan hệ giữa bên bảo lãnh và bên nhận bảo lãnh.txt
# Đã lưu: data_new\bo_luat_dan_su\bo_luat_dan_su\Chương XV\Điều 340. Quyền yêu cầu của bên bảo lãnh.txt
# Đã lưu: data_new\bo_luat_dan_su\bo_luat_dan_su\Chương XV\Điều 341. Miễn việc thực hiện nghĩa vụ bảo lãnh.txt
# Đã lưu: data_new\bo_luat_dan_su\bo_luat_dan_su\Chương XV\Điều 342. Trách nhiệm dân sự của bên bảo lãnh.txt
# Đã lưu: data_new\bo_luat_dan_su\bo_luat_dan_su\Chương XV\Điều 343. Chấm dứt bảo lãnh.txt
# Đã lưu: data_new\bo_luat_dan_su\bo_luat_dan_su\Chương XV\Điều 344. Bảo đảm bằng tín chấp của tổ chức chính trị - xã hội.txt
# Đã lưu: data_new\bo_luat_dan_su\bo_luat_dan_su\Chương XV\Điều 345. Hình thức, nội dung tín chấp.txt
# Đã lưu: data_new\bo_luat_dan_su\bo_luat_dan_su\Chương XV\Điều 346. Cầm giữ tài sản.txt
# Đã lưu: data_new\bo_luat_dan_su\bo_luat_dan_su\Chương XV\Điều 347. Xác lập cầm giữ tài sản.txt
# Đã lưu: data_new\bo_luat_dan_su\bo_luat_dan_su\Chương XV\Điều 348. Quyền của bên cầm giữ.txt
# Đã lưu: data_new\bo_luat_dan_su\bo_luat_dan_su\Chương XV\Điều 349. Nghĩa vụ của bên cầm giữ.txt
# Đã lưu: data_new\bo_luat_dan_su\bo_luat_dan_su\Chương XV\Điều 350. Chấm dứt cầm giữ.txt
# Đã lưu: data_new\bo_luat_dan_su\bo_luat_dan_su\Chương XV\Điều 351. Trách nhiệm dân sự do vi phạm nghĩa vụ.txt
# Đã lưu: data_new\bo_luat_dan_su\bo_luat_dan_su\Chương XV\Điều 352. Trách nhiệm tiếp tục thực hiện nghĩa vụ.txt
# Đã lưu: data_new\bo_luat_dan_su\bo_luat_dan_su\Chương XV\Điều 353. Chậm thực hiện nghĩa vụ.txt
# Đã lưu: data_new\bo_luat_dan_su\bo_luat_dan_su\Chương XV\Điều 354. Hoãn thực hiện nghĩa vụ.txt
# Đã lưu: data_new\bo_luat_dan_su\bo_luat_dan_su\Chương XV\Điều 355. Chậm tiếp nhận việc thực hiện nghĩa vụ.txt
# Đã lưu: data_new\bo_luat_dan_su\bo_luat_dan_su\Chương XV\Điều 356. Trách nhiệm do không thực hiện nghĩa vụ giao vật.txt
# Đã lưu: data_new\bo_luat_dan_su\bo_luat_dan_su\Chương XV\Điều 357. Trách nhiệm do chậm thực hiện nghĩa vụ trả tiền.txt
# Đã lưu: data_new\bo_luat_dan_su\bo_luat_dan_su\Chương XV\Điều 468 của Bộ luật này..txt
# Đã lưu: data_new\bo_luat_dan_su\bo_luat_dan_su\Chương XV\Điều 358. Trách nhiệm do không thực hiện hoặc không được thực hiện một.txt
# Đã lưu: data_new\bo_luat_dan_su\bo_luat_dan_su\Chương XV\Điều 359. Trách nhiệm do chậm tiếp nhận việc thực hiện nghĩa vụ.txt
# Đã lưu: data_new\bo_luat_dan_su\bo_luat_dan_su\Chương XV\Điều 360. Trách nhiệm bồi thường thiệt hại do vi phạm nghĩa vụ.txt
# Đã lưu: data_new\bo_luat_dan_su\bo_luat_dan_su\Chương XV\Điều 361. Thiệt hại do vi phạm nghĩa vụ.txt
# Đã lưu: data_new\bo_luat_dan_su\bo_luat_dan_su\Chương XV\Điều 362. Nghĩa vụ ngăn chặn, hạn chế thiệt hại.txt
# Đã lưu: data_new\bo_luat_dan_su\bo_luat_dan_su\Chương XV\Điều 363. Bồi thường thiệt hại trong trường hợp bên bị vi phạm có lỗi.txt
# Đã lưu: data_new\bo_luat_dan_su\bo_luat_dan_su\Chương XV\Điều 364. Lỗi trong trách nhiệm dân sự.txt
# Đang xử lý file: law_prediction-master\law_prediction-master\data_crawl\bo_luat_hang_hai\hang_hai.doc
# Đã lưu: data_new\bo_luat_hang_hai\hang_hai\Chương 1\Điều 1.txt
# Đang xử lý file: law_prediction-master\law_prediction-master\data_crawl\bo_luat_hinh_su\hinh_su.doc
